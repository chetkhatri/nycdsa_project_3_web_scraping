# %%
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
f = open("test_name.txt","r")  
name = []
for line in f:
    line = line.strip()
    name.append(line)
# print(name)

# %%
f = open("test_state.txt","r")  
state = []
for line in f:
    line = line.strip()
    state.append(line)
# print(state)

# %%
f = open("test_date.txt","r")  
year = []
for line in f:
    line = line.strip()
    line = re.findall('^.*,\s*(.*)$', line)[0]
    year.append(line)
# print(year)

# %%
f = open("test_visitor.txt","r")  
visitor = []
for line in f:
    line = line.strip()
    line = line.replace(",", "")
    visitor.append(int(line))
# print(visitor)

# %%
park_data = {"name":name,"state":state,"year":year,"visitor":visitor}
park_data_frame = pd.DataFrame(park_data, columns = ["name","state","year","visitor"])
# park_data_frame
# Out:
#                             name                         state  year   visitor
# 0                         Acadia                         Maine  1919   2563129
# 1                 American Samoa                American Samoa  1988     13953
# 2                         Arches                          Utah  1971   1284767
# 3                       Badlands                  South Dakota  1978    868094
# 4                       Big Bend                         Texas  1944    314102
# 5                       Biscayne                       Florida  1980    525745
# 6   Black Canyon of the Gunnison                      Colorado  1999    183045
# 7                   Bryce Canyon                          Utah  1928   1435741
# 8                    Canyonlands                          Utah  1964    542431
# 9                   Capitol Reef                          Utah  1971    786514
# 10              Carlsbad Caverns                    New Mexico  1930   1497889
# 11               Channel Islands                    California  1980    342161
# 12                      Congaree                South Carolina  2003    120122
# 13                   Crater Lake                        Oregon  1902    535508
# 14               Cuyahoga Valley                          Ohio  2000   2189849
# 15                  Death Valley                    California  1994   1101312
# 16                        Denali                        Alaska  1917    531315
# 17                  Dry Tortugas                       Florida  1992     64865
# 18                    Everglades                       Florida  1934   1110901
# 19           Gates of the Arctic                        Alaska  1980     12669
# 20                       Glacier                       Montana  1910   2338528
# 21                   Glacier Bay                        Alaska  1980    500727
# 22                  Grand Canyon                       Arizona  1919   4756771
# 23                   Grand Teton                       Wyoming  1929   2791392
# 24                   Great Basin                        Nevada  1986    107526
# 25              Great Sand Dunes                      Colorado  2004    271774
# 26         Great Smoky Mountains                     Tennessee  1934  10099276
# 27           Guadalupe Mountains                         Texas  1966    166868
# 28              Hawaii Volcanoes                        Hawaii  1916   1693005
# 29                   Hot Springs                      Arkansas  1921   1424484
# 30                   Isle Royale                      Michigan  1940     14560
# 31                   Joshua Tree                    California  1994   1589904
# 32                        Katmai                        Alaska  1980     30896
# 33                  Kenai Fjords                        Alaska  1980    270666
# 34                  Kings Canyon                    California  1940    502268
# 35                  Kobuk Valley                        Alaska  1980     16875
# 36                    Lake Clark                        Alaska  1980     16100
# 37               Lassen Volcanic                    California  1916    432977
# 38                  Mammoth Cave                      Kentucky  1941    522628
# 39                    Mesa Verde                      Colorado  1906    501563
# 40                 Mount Rainier                    Washington  1899   1264259
# 41                North Cascades                    Washington  1968     23865
# 42                       Olympic                    Washington  1938   3243872
# 43              Petrified Forest                       Arizona  1962    836799
# 44                     Pinnacles                    California  2013    196635
# 45                       Redwood                    California  1968    429166
# 46                Rocky Mountain                      Colorado  1915   3434751
# 47                       Saguaro                       Arizona  1994    673572
# 48                       Sequoia                    California  1890   1039137
# 49                    Shenandoah                      Virginia  1926   1255321
# 50            Theodore Roosevelt                  North Dakota  1978    559580
# 51                Virgin Islands  United States Virgin Islands  1956    426930
# 52                     Voyageurs                     Minnesota  1971    239160
# 53                     Wind Cave                  South Dakota  1903    542022
# 54                   Yellowstone                       Wyoming  1872   3513484
# 55                      Yosemite                    California  1890   3882642
# 56                          Zion                          Utah  1919   3189696

# %%
park_data_frame.to_csv('../park_data_frame_wiki.csv', index=False)
# park_data_frame_wiki = pd.read_csv('../park_data_frame_wiki.csv')
# park_data_frame_wiki
